# %% [markdown]
# # `DataFrame` Example
#
# In this lecture I'm going to walk through a basic data cleaning process with you and introduce you to a few more pandas API functions.

# %%
# Let's start by bringing in pandas
import pandas as pd
# And load our dataset. We're going to be cleaning the list of presidents in the US from wikipedia
df=pd.read_csv("datasets/presidents.csv")
# And lets just take a look at some of the data
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# 3  85 years, 104 days
# 4   73 years, 67 days

# %%
# Ok, we have some presidents, some dates, I see a bunch of footnotes in the "Born" column which might cause
# issues. Let's start with cleaning up that name into firstname and lastname. I'm going to tackle this with
# a regex. So I want to create two new columns and apply a regex to the projection of the "President" column.

# Here's one solution, we could make a copy of the President column
df["First"]=df['President']
# Then we can call replace() and just have a pattern that matches the last name and set it to an empty string
df["First"]=df["First"].replace("[ ].*", "", regex=True)
# Now let's take a look
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First
# 0  67 years, 295 days  George
# 1  90 years, 247 days    John
# 2   83 years, 82 days  Thomas
# 3  85 years, 104 days   James
# 4   73 years, 67 days   James

# %%
# That works, but it's kind of gross. And it's slow, since we had to make a full copy of a column then go
# through and update strings. There are a few other ways we can deal with this. Let me show you the most 
# general one first, and that's called the apply() function. Let's drop the column we made first
del(df["First"])

# The apply() function on a dataframe will take some arbitrary function you have written and apply it to
# either a Series (a single column) or DataFrame across all rows or columns. Lets write a function which
# just splits a string into two pieces using a single row of data
def splitname(row):
    # The row is a single Series object which is a single row indexed by column values
    # Let's extract the firstname and create a new entry in the series
    row['First']=row['President'].split(" ")[0]
    # Let's do the same with the last word in the string
    row['Last']=row['President'].split(" ")[-1]
    # Now we just return the row and the pandas .apply() will take of merging them back into a DataFrame
    return row

# Now if we apply this to the dataframe indicating we want to apply it across columns
df=df.apply(splitname, axis='columns')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# 2   83 years, 82 days  Thomas   Jefferson
# 3  85 years, 104 days   James     Madison
# 4   73 years, 67 days   James      Monroe

# %%
# Pretty questionable as to whether that is less gross, but it achieves the result and I find that I use the
# apply() function regularly in my work. The pandas series has a couple of other nice convenience functions
# though, and the next I would like to touch on is called .extract(). Lets drop our firstname and lastname.
del(df['First'])
del(df['Last'])

# Extract takes a regular expression as input and specifically requires you to set capture groups that
# correspond to the output columns you are interested in. And, this is a great place for you to pause the
# video and reflect - if you were going to write a regular expression that returned groups and just had the
# firstname and lastname in it, what would that look like?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'First'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 4
#       1 # Pretty questionable as to whether that is less gross, but it achieves the result and I find that I use the
#       2 # apply() function regularly in my work. The pandas series has a couple of other nice convenience functions
#       3 # though, and the next I would like to touch on is called .extract(). Lets drop our firstname and lastname.
# ----> 4 del(df['First'])
#       5 del(df['Last'])
#       7 # Extract takes a regular expression as input and specifically requires you to set capture groups that
#       8 # correspond to the output columns you are interested in. And, this is a great place for you to pause the
#       9 # video and reflect - if you were going to write a regular expression that returned groups and just had the
#      10 # firstname and lastname in it, what would that look like?
#      11
#      12 # Here's my solution, where we match three groups but only return two, the first and the last name
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py:4243, in NDFrame.__delitem__(self, key)
#    4238             deleted = True
#    4239 if not deleted:
#    4240     # If the above loop ran and didn't delete anything because
#    4241     # there was no match, this call should raise the appropriate
#    4242     # exception:
# -> 4243     loc = self.axes[-1].get_loc(key)
#    4244     self._mgr = self._mgr.idelete(loc)
#    4246 # delete from the caches
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'First'

# %%
# Here's my solution, where we match three groups but only return two, the first and the last name
pattern="(^[\w]*)(?:.* )([\w]*$)"

# Now the extract function is built into the str attribute of the Series object, so we can call it
# using Series.str.extract(pattern)
df[["First", "Last"]]=df["President"].str.extract(pattern)
del(df['President'])
df.head(10)
# Out:
#     #             Born      Age atstart of presidency  \
# 0   1  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1   2  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2   3  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3   4  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4   5     Apr 28, 1758  58 years, 310 daysMar 4, 1817
# 5   6     Jul 11, 1767  57 years, 236 daysMar 4, 1825
# 6   7     Mar 15, 1767  61 years, 354 daysMar 4, 1829
# 7   8      Dec 5, 1782   54 years, 89 daysMar 4, 1837
# 8   9      Feb 9, 1773   68 years, 23 daysMar 4, 1841
# 9  10     Mar 29, 1790    51 years, 6 daysApr 4, 1841
#
#             Age atend of presidency Post-presidencytimespan          Died  \
# 0      65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1     65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2     65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3     65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4     66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
# 5     61 years, 236 daysMar 4, 1829      18 years, 356 days  Feb 23, 1848
# 6     69 years, 354 daysMar 4, 1837        8 years, 96 days   Jun 8, 1845
# 7      58 years, 89 daysMar 4, 1841      21 years, 142 days  Jul 24, 1862
# 8  68 years, 54 days Apr 4, 1841[b]                     NaN   Apr 4, 1841
# 9     54 years, 340 daysMar 4, 1845      16 years, 320 days  Jan 18, 1862
#
#                   Age    First        Last
# 0  67 years, 295 days   George  Washington
# 1  90 years, 247 days     John       Adams
# 2   83 years, 82 days   Thomas   Jefferson
# 3  85 years, 104 days    James     Madison
# 4   73 years, 67 days    James      Monroe
# 5  80 years, 227 days     John       Adams
# 6   78 years, 85 days   Andrew     Jackson
# 7  79 years, 231 days   Martin       Buren
# 8   68 years, 54 days  William    Harrison
# 9  71 years, 295 days     John       Tyler

# %%
# So that looks pretty nice, other than the column names. But if we name the groups we get named columns out
pattern="(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"

# Now call extract
names=df["President"].str.extract(pattern).head()
names
# Out:
#     First        Last
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
# And we can just copy these into our main dataframe if we want to
df["First"]=names["First"]
df["Last"]=names["Last"]
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# 2   83 years, 82 days  Thomas   Jefferson
# 3  85 years, 104 days   James     Madison
# 4   73 years, 67 days   James      Monroe

# %%
# It's worth looking at the pandas str module for other functions which have been written specifically
# to clean up strings in DataFrames, and you can find that in the docs in the Working with Text
# section: https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html

# %%
# Now lets move on to clean up that Born column. First, let's get rid of anything that isn't in the
# pattern of Month Day and Year.
df["Born"]=df["Born"].str.extract("([\w]{3} [\w]{1,2}, [\w]{4})")
df["Born"].head()
# Out:
# 0    Feb 22, 1732
# 1    Oct 30, 1735
# 2    Apr 13, 1743
# 3    Mar 16, 1751
# 4    Apr 28, 1758
# Name: Born, dtype: object

# %%
# So, that cleans up the date format. But I'm going to foreshadow something else here - the type of this
# column is object, and we know that's what pandas uses when it is dealing with string. But pandas actually
# has really interesting date/time features - in fact, that's one of the reasons Wes McKinney put his efforts
# into the library, to deal with financial transactions. So if I were building this out, I would actually
# update this column to the write data type as well
df["Born"]=pd.to_datetime(df["Born"])
df["Born"].head()
# Out:
# 0   1732-02-22
# 1   1735-10-30
# 2   1743-04-13
# 3   1751-03-16
# 4   1758-04-28
# Name: Born, dtype: datetime64[ns]

# %%
# This would make subsequent processing on the dataframe around dates, such as getting every President who
# was born in a given time span, much easier.

# %% [markdown]
# Now, most of the other columns in this dataset I would clean in a similar fashion. And this would be a good practice activity for you, so I would recommend that you pause the video, open up the notebook for the lecture if you don't already have it opened, and then finish cleaning up this dataframe. In this lecture I introduced you to the str module which has a number of important functions for cleaning pandas dataframes. You don't have to use these - I actually use apply() quite a bit myself, especially if I don't need high performance data cleaning because my dataset is small. But the str functions are incredibly useful and build on your existing knowledge of regular expressions, and because they are vectorized they are efficient to use as well.

# %%
df.columns = [col.lower().strip() for col in df.columns]
df.head()
# Out:
#    #          president       born      age atstart of presidency  \
# 0  1  George Washington 1732-02-22  57 years, 67 daysApr 30, 1789
# 1  2         John Adams 1735-10-30  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson 1743-04-13  57 years, 325 daysMar 4, 1801
# 3  4      James Madison 1751-03-16  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe 1758-04-28  58 years, 310 daysMar 4, 1817
#
#          age atend of presidency post-presidencytimespan          died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   age   first        last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# 2   83 years, 82 days  Thomas   Jefferson
# 3  85 years, 104 days   James     Madison
# 4   73 years, 67 days   James      Monroe

# %%
df.rename(columns={'age atstart of presidency': 'start', 'age atend of presidency': 'end', 'post-presidencytimespan': 'post'}, inplace=True)

# %%
df.set_index('#')
# Out:
#                 president       born                           start  \
# #
# 1       George Washington 1732-02-22   57 years, 67 daysApr 30, 1789
# 2              John Adams 1735-10-30   61 years, 125 daysMar 4, 1797
# 3        Thomas Jefferson 1743-04-13   57 years, 325 daysMar 4, 1801
# 4           James Madison 1751-03-16   57 years, 353 daysMar 4, 1809
# 5            James Monroe 1758-04-28   58 years, 310 daysMar 4, 1817
# 6       John Quincy Adams 1767-07-11   57 years, 236 daysMar 4, 1825
# 7          Andrew Jackson 1767-03-15   61 years, 354 daysMar 4, 1829
# 8        Martin Van Buren 1782-12-05    54 years, 89 daysMar 4, 1837
# 9     William H. Harrison 1773-02-09    68 years, 23 daysMar 4, 1841
# 10             John Tyler 1790-03-29     51 years, 6 daysApr 4, 1841
# 11          James K. Polk 1795-11-02   49 years, 122 daysMar 4, 1845
# 12         Zachary Taylor 1784-11-24   64 years, 100 daysMar 4, 1849
# 13       Millard Fillmore 1800-01-07   50 years, 183 daysJul 9, 1850
# 14        Franklin Pierce 1804-11-23   48 years, 101 daysMar 4, 1853
# 15         James Buchanan 1791-04-23   65 years, 315 daysMar 4, 1857
# 16        Abraham Lincoln 1809-02-12    52 years, 20 daysMar 4, 1861
# 17         Andrew Johnson 1808-12-29  56 years, 107 daysApr 15, 1865
# 18       Ulysses S. Grant 1822-04-27   46 years, 311 daysMar 4, 1869
# 19    Rutherford B. Hayes 1822-10-04   54 years, 151 daysMar 4, 1877
# 20      James A. Garfield 1831-11-19   49 years, 105 daysMar 4, 1881
# 21      Chester A. Arthur 1829-10-05  51 years, 349 daysSep 19, 1881
# 22       Grover Cleveland 1837-03-18   47 years, 351 daysMar 4, 1885
# 23      Benjamin Harrison 1833-08-20   55 years, 196 daysMar 4, 1889
# 24       Grover Cleveland 1837-03-18   55 years, 351 daysMar 4, 1893
# 25       William McKinley 1843-01-29    54 years, 34 daysMar 4, 1897
# 26     Theodore Roosevelt 1858-10-27  42 years, 322 daysSep 14, 1901
# 27        William H. Taft 1857-09-15   51 years, 170 daysMar 4, 1909
# 28         Woodrow Wilson 1856-12-28    56 years, 66 daysMar 4, 1913
# 29      Warren G. Harding 1865-11-02   55 years, 122 daysMar 4, 1921
# 30        Calvin Coolidge 1872-07-04    51 years, 29 daysAug 2, 1923
# 31         Herbert Hoover 1874-08-10   54 years, 206 daysMar 4, 1929
# 32  Franklin D. Roosevelt 1882-01-30    51 years, 33 daysMar 4, 1933
# 33        Harry S. Truman 1884-05-08  60 years, 339 daysApr 12, 1945
# 34   Dwight D. Eisenhower 1890-10-14   62 years, 98 daysJan 20, 1953
# 35        John F. Kennedy 1917-05-29  43 years, 236 daysJan 20, 1961
# 36      Lyndon B. Johnson 1908-08-27   55 years, 87 daysNov 22, 1963
# 37          Richard Nixon 1913-01-09   56 years, 11 daysJan 20, 1969
# 38            Gerald Ford 1913-07-14    61 years, 26 daysAug 9, 1974
# 39           Jimmy Carter 1924-10-01  52 years, 111 daysJan 20, 1977
# 40          Ronald Reagan 1911-02-06  69 years, 349 daysJan 20, 1981
# 41      George H. W. Bush 1924-06-12  64 years, 222 daysJan 20, 1989
# 42           Bill Clinton 1946-08-19  46 years, 154 daysJan 20, 1993
# 43         George W. Bush 1946-07-06  54 years, 198 daysJan 20, 2001
# 44           Barack Obama 1961-08-04  47 years, 169 daysJan 20, 2009
#
#                                   end                   post          died  \
# #
# 1        65 years, 10 daysMar 4, 1797      2 years, 285 days  Dec 14, 1799
# 2       65 years, 125 daysMar 4, 1801     25 years, 122 days   Jul 4, 1826
# 3       65 years, 325 daysMar 4, 1809     17 years, 122 days   Jul 4, 1826
# 4       65 years, 353 daysMar 4, 1817     19 years, 116 days  Jun 28, 1836
# 5       66 years, 310 daysMar 4, 1825      6 years, 122 days   Jul 4, 1831
# 6       61 years, 236 daysMar 4, 1829     18 years, 356 days  Feb 23, 1848
# 7       69 years, 354 daysMar 4, 1837       8 years, 96 days   Jun 8, 1845
# 8        58 years, 89 daysMar 4, 1841     21 years, 142 days  Jul 24, 1862
# 9    68 years, 54 days Apr 4, 1841[b]                    NaN   Apr 4, 1841
# 10      54 years, 340 daysMar 4, 1845     16 years, 320 days  Jan 18, 1862
# 11      53 years, 122 daysMar 4, 1849               103 days  Jun 15, 1849
# 12   65 years, 227 daysJul 9, 1850[b]                    NaN   Jul 9, 1850
# 13       53 years, 56 daysMar 4, 1853       21 years, 4 days   Mar 8, 1874
# 14      52 years, 101 daysMar 4, 1857     12 years, 218 days   Oct 8, 1869
# 15      69 years, 315 daysMar 4, 1861       7 years, 89 days   Jun 1, 1868
# 16   56 years, 62 daysApr 15, 1865[b]                    NaN  Apr 15, 1865
# 17       60 years, 65 daysMar 4, 1869      6 years, 149 days  Jul 31, 1875
# 18      54 years, 311 daysMar 4, 1877      8 years, 141 days  Jul 23, 1885
# 19      58 years, 151 daysMar 4, 1881     11 years, 319 days  Jan 17, 1893
# 20  49 years, 304 daysSep 19, 1881[b]                    NaN  Sep 19, 1881
# 21      55 years, 150 daysMar 4, 1885       1 year, 259 days  Nov 18, 1886
# 22      51 years, 351 daysMar 4, 1889     4 years, 0 days[c]  Jun 24, 1908
# 23      59 years, 196 daysMar 4, 1893        8 years, 9 days  Mar 13, 1901
# 24      59 years, 351 daysMar 4, 1897  11 years, 112 days[d]  Jun 24, 1908
# 25  58 years, 228 daysSep 14, 1901[b]                    NaN  Sep 14, 1901
# 26      50 years, 128 daysMar 4, 1909      9 years, 308 days   Jan 6, 1919
# 27      55 years, 170 daysMar 4, 1913       17 years, 4 days   Mar 8, 1930
# 28       64 years, 66 daysMar 4, 1921      2 years, 336 days   Feb 3, 1924
# 29   57 years, 273 daysAug 2, 1923[b]                    NaN   Aug 2, 1923
# 30      56 years, 243 daysMar 4, 1929      3 years, 307 days   Jan 5, 1933
# 31      58 years, 206 daysMar 4, 1933     31 years, 230 days  Oct 20, 1964
# 32   63 years, 72 daysApr 12, 1945[b]                    NaN  Apr 12, 1945
# 33     68 years, 257 daysJan 20, 1953     19 years, 341 days  Dec 26, 1972
# 34      70 years, 98 daysJan 20, 1961       8 years, 67 days  Mar 28, 1969
# 35  46 years, 177 daysNov 22, 1963[b]                    NaN  Nov 22, 1963
# 36     60 years, 146 daysJan 20, 1969        4 years, 2 days  Jan 22, 1973
# 37   61 years, 212 daysAug 9, 1974[e]     19 years, 256 days  Apr 22, 1994
# 38     63 years, 190 daysJan 20, 1977     29 years, 340 days  Dec 26, 2006
# 39     56 years, 111 daysJan 20, 1981     38 years, 175 days      (living)
# 40     77 years, 349 daysJan 20, 1989     15 years, 137 days   Jun 5, 2004
# 41     68 years, 222 daysJan 20, 1993     25 years, 314 days  Nov 30, 2018
# 42     54 years, 154 daysJan 20, 2001     18 years, 175 days      (living)
# 43     62 years, 198 daysJan 20, 2009     10 years, 175 days      (living)
# 44     55 years, 169 daysJan 20, 2017      2 years, 175 days      (living)
#
#                    age   first        last
# #
# 1   67 years, 295 days  George  Washington
# 2   90 years, 247 days    John       Adams
# 3    83 years, 82 days  Thomas   Jefferson
# 4   85 years, 104 days   James     Madison
# 5    73 years, 67 days   James      Monroe
# 6   80 years, 227 days     NaN         NaN
# 7    78 years, 85 days     NaN         NaN
# 8   79 years, 231 days     NaN         NaN
# 9    68 years, 54 days     NaN         NaN
# 10  71 years, 295 days     NaN         NaN
# 11  53 years, 225 days     NaN         NaN
# 12  65 years, 227 days     NaN         NaN
# 13   74 years, 60 days     NaN         NaN
# 14  64 years, 319 days     NaN         NaN
# 15   77 years, 39 days     NaN         NaN
# 16   56 years, 62 days     NaN         NaN
# 17  66 years, 214 days     NaN         NaN
# 18   63 years, 87 days     NaN         NaN
# 19  70 years, 105 days     NaN         NaN
# 20  49 years, 304 days     NaN         NaN
# 21   57 years, 44 days     NaN         NaN
# 22   71 years, 98 days     NaN         NaN
# 23  67 years, 205 days     NaN         NaN
# 24   71 years, 98 days     NaN         NaN
# 25  58 years, 228 days     NaN         NaN
# 26   60 years, 71 days     NaN         NaN
# 27  72 years, 174 days     NaN         NaN
# 28   67 years, 37 days     NaN         NaN
# 29  57 years, 273 days     NaN         NaN
# 30  60 years, 185 days     NaN         NaN
# 31   90 years, 71 days     NaN         NaN
# 32   63 years, 72 days     NaN         NaN
# 33  88 years, 232 days     NaN         NaN
# 34  78 years, 165 days     NaN         NaN
# 35  46 years, 177 days     NaN         NaN
# 36  64 years, 148 days     NaN         NaN
# 37  81 years, 103 days     NaN         NaN
# 38  93 years, 165 days     NaN         NaN
# 39  94 years, 286 days     NaN         NaN
# 40  93 years, 120 days     NaN         NaN
# 41  94 years, 171 days     NaN         NaN
# 42  72 years, 329 days     NaN         NaN
# 43    73 years, 8 days     NaN         NaN
# 44  57 years, 344 days     NaN         NaN

# %%
df.head(10)
# Out:
#    #          president       born      start        end                post  \
# 0  1  George Washington 1732-02-22 1789-04-30 1797-03-04   2 years, 285 days
# 1  2         John Adams 1735-10-30 1797-03-04 1801-03-04  25 years, 122 days
# 2  3   Thomas Jefferson 1743-04-13 1801-03-04 1809-03-04  17 years, 122 days
# 3  4      James Madison 1751-03-16 1809-03-04 1817-03-04  19 years, 116 days
# 4  5       James Monroe 1758-04-28 1817-03-04 1825-03-04   6 years, 122 days
#
#         died                 age   first        last    period
# 0 1799-12-14  67 years, 295 days  George  Washington 2865 days
# 1 1826-07-04  90 years, 247 days    John       Adams 1460 days
# 2 1826-07-04   83 years, 82 days  Thomas   Jefferson 2922 days
# 3 1836-06-28  85 years, 104 days   James     Madison 2922 days
# 4 1831-07-04   73 years, 67 days   James      Monroe 2922 days

# %%
pattern = "(\w{3}\s\d{1,2}, \d{4})"
df['died']=df['died'].str.extract(pattern)
df['died']=pd.to_datetime(df['died'])

# %%
pattern = "(\w{3}\s\d{1,2}, \d{4}$)"
df['start']=df['start'].str.extract(pattern)
df['start']=pd.to_datetime(df['start'])

# %%
pattern = "(\w{3}\s\d{1,2}, \d{4}$)"
df['end']=df['end'].str.extract(pattern)
df['end']=pd.to_datetime(df['end'])

# %%
df['period'] = df['end'] - df['start']
df.dropna(inplace=True)
